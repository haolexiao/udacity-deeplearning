# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
count = [['UNK', -1]]
count.extend(collections.Counter(words).most_common(vocabulary_size - 1))

# %%
print(len(count))
print(count[0:10])
# Out:
# 50000
# [['UNK', -1], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.294823
# Nearest to can: cooler, gregorio, feelin, bushman, blackbody, crafting, galveston, flagellate,
# Nearest to than: swells, raoul, flirty, canc, basis, inhabited, hemoglobin, matching,
# Nearest to other: symbolizing, quark, attached, kissinger, lh, simple, lebowski, flanks,
# Nearest to between: holbach, ornament, autopilot, pills, programmable, increased, posits, drainage,
# Nearest to will: tending, stovl, deniers, trap, alarms, simmered, purchase, romania,
# Nearest to on: orcus, econometric, blunt, violated, biochemist, miss, drift, userbase,
# Nearest to a: teamsters, catastrophe, guinean, configurable, perverse, opanal, of, factorizations,
# Nearest to from: mint, season, autocrat, daiko, radios, lensing, bacterial, whomever,
# Nearest to are: jelly, months, kyle, depict, minstrel, stoichiometric, bumpy, rivest,
# Nearest to while: tain, argumentative, damien, inspiration, balloons, niacin, bouvet, ile,
# Nearest to by: friedrich, surreal, colorful, luxemburg, intercity, songwriter, boys, carcasses,
# Nearest to who: ochre, nic, sidespin, apportioned, alighieri, refrigeration, cretians, lsd,
# Nearest to they: cryogenics, stun, initialism, theropod, constructivist, cries, sterne, sagan,
# Nearest to i: gauze, passed, requisite, trujillo, camden, captors, sprengel, robertson,
# Nearest to no: utilize, plaintiffs, eicher, vocalization, eagerness, analgesics, knitters, venezuelan,
# Nearest to up: serial, calculus, ribbon, migrants, meningitis, spread, leans, typhoon,
# Average loss at step 2000: 4.361751
# Average loss at step 4000: 3.860888
# Average loss at step 6000: 3.796328
# Average loss at step 8000: 3.680934
# Average loss at step 10000: 3.614846
# Nearest to can: would, will, may, could, cooler, leclerc, but, ypres,
# Nearest to than: barclay, catastrophe, huntley, swells, energetic, flirty, cary, curtin,
# Nearest to other: turned, houdini, some, lebowski, magellan, encrypting, dusty, merci,
# Nearest to between: with, amerindians, holbach, oftentimes, autopilot, of, classicist, da,
# Nearest to will: can, would, improvising, tending, purchase, stovl, hence, may,
# Nearest to on: in, through, at, by, thoughtful, libel, novak, indulgences,
# Nearest to a: the, klaus, his, jeanne, factorizations, himself, sounding, bagpipes,
# Nearest to from: hawala, deborah, with, into, incorruptible, accentuated, at, swimmers,
# Nearest to are: were, is, rivest, have, dry, was, resembles, centralized,
# Nearest to while: tain, argumentative, underlying, damien, relaunched, district, erupt, veneto,
# Nearest to by: was, as, intercity, obstructions, kla, in, be, moldovan,
# Nearest to who: he, and, also, not, arches, teleplay, apportioned, which,
# Nearest to they: he, there, it, you, not, sagan, mirabilis, cries,
# Nearest to i: hardened, propose, sister, gauze, bir, abl, denigrating, girl,
# Nearest to no: it, convoluted, knitters, tendon, supplying, yggdrasil, plaintiffs, plagiarism,
# Nearest to up: serial, homeric, meningitis, ribbon, examine, yugoslavia, harpercollins, calculus,
# Average loss at step 12000: 3.601016
# Average loss at step 14000: 3.571305
# Average loss at step 16000: 3.409949
# Average loss at step 18000: 3.455352
# Average loss at step 20000: 3.543174
# Nearest to can: may, would, could, will, cannot, might, must, should,
# Nearest to than: or, huntley, barclay, problematic, energetic, catastrophe, dictatorial, deprecating,
# Nearest to other: some, various, turned, many, derg, dusty, secondo, magellan,
# Nearest to between: with, in, from, amerindians, da, classicist, rachael, into,
# Nearest to will: would, can, may, could, should, might, improvising, to,
# Nearest to on: in, at, through, kalashnikov, playlist, upon, aeroflot, novak,
# Nearest to a: the, this, masuria, sounding, any, no, cooperating, pepe,
# Nearest to from: into, in, at, between, hawala, during, cougars, with,
# Nearest to are: were, is, have, was, psychosocial, organizing, resembles, mohenjo,
# Nearest to while: underlying, district, relaunched, unrestricted, rerum, veneto, argumentative, tain,
# Nearest to by: into, in, be, with, intercity, was, against, were,
# Nearest to who: he, which, also, then, pio, they, often, factorial,
# Nearest to they: he, there, we, you, it, not, who, she,
# Nearest to i: ii, hardened, mycelium, propose, mandragora, girl, she, abl,
# Nearest to no: convoluted, a, any, tendon, mobster, naci, swabia, castor,
# Nearest to up: out, serial, meningitis, ribbon, spread, calculus, chapels, accumulated,
# Average loss at step 22000: 3.501959
# Average loss at step 24000: 3.489029
# Average loss at step 26000: 3.482375
# Average loss at step 28000: 3.483282
# Average loss at step 30000: 3.499434
# Nearest to can: may, would, could, will, must, might, cannot, should,
# Nearest to than: huntley, problematic, barclay, energetic, catastrophe, much, beatified, dictatorial,
# Nearest to other: various, some, many, secondo, several, commotion, these, derg,
# Nearest to between: with, da, amerindians, from, rachael, in, surnamed, classicist,
# Nearest to will: can, would, could, may, should, might, must, to,
# Nearest to on: upon, in, through, until, at, from, kalashnikov, about,
# Nearest to a: the, sounding, frenchmen, no, their, another, any, jonas,
# Nearest to from: into, in, during, of, between, including, with, on,
# Nearest to are: were, have, is, include, these, dangers, mohenjo, resembles,
# Nearest to while: although, when, but, though, under, relaunched, erupt, appliance,
# Nearest to by: under, with, was, kla, were, intercity, flutist, as,
# Nearest to who: he, they, pio, also, and, which, there, saiyan,
# Nearest to they: there, he, we, you, it, not, who, she,
# Nearest to i: ii, she, you, hardened, mandragora, we, mycelium, g,
# Nearest to no: any, convoluted, a, mobster, operations, tendon, naci, harmon,
# Nearest to up: out, him, serial, meningitis, examine, accumulated, ribbon, chapels,
# Average loss at step 32000: 3.502967
# Average loss at step 34000: 3.494054
# Average loss at step 36000: 3.455741
# Average loss at step 38000: 3.304033
# Average loss at step 40000: 3.426044
# Nearest to can: will, could, may, would, must, might, should, cannot,
# Nearest to than: or, huntley, problematic, barclay, much, dictatorial, saviour, beatified,
# Nearest to other: various, secondo, some, commotion, aucklanders, houdini, researcher, encrypting,
# Nearest to between: with, da, amerindians, oftentimes, surnamed, from, over, interdict,
# Nearest to will: can, would, could, may, must, should, might, cannot,
# Nearest to on: upon, at, through, about, during, testes, lysosome, unsatisfied,
# Nearest to a: sounding, any, konkan, surviving, the, momenta, another, bajan,
# Nearest to from: into, in, during, rolland, hawala, between, repeatable, sears,
# Nearest to are: were, is, have, resembles, be, include, lycanthropy, hpv,
# Nearest to while: when, although, though, but, before, however, relaunched, where,
# Nearest to by: with, kla, fibers, robbed, under, ghidorah, byproducts, for,
# Nearest to who: he, pio, which, often, also, they, chestnuts, spitzer,
# Nearest to they: we, you, there, he, it, i, not, she,
# Nearest to i: you, ii, we, she, he, they, propose, t,
# Nearest to no: any, another, curtin, operations, convoluted, mobster, a, radar,
# Nearest to up: out, him, them, accumulated, down, chapels, into, meningitis,
# Average loss at step 42000: 3.436175
# Average loss at step 44000: 3.451187
# Average loss at step 46000: 3.445999
# Average loss at step 48000: 3.351103
# Average loss at step 50000: 3.382387
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to than: huntley, or, much, but, introspection, problematic, dictatorial, catastrophe,
# Nearest to other: various, many, commotion, different, these, houdini, including, yassir,
# Nearest to between: with, da, amerindians, among, into, in, interdict, classicist,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to on: upon, in, through, at, for, into, about, following,
# Nearest to a: sounding, the, any, another, orbs, ej, no, paradigmatic,
# Nearest to from: into, in, during, hawala, barbaric, ect, on, wainwright,
# Nearest to are: were, is, have, these, resembles, be, tentative, those,
# Nearest to while: when, although, however, though, but, after, where, before,
# Nearest to by: under, through, was, with, nationalities, against, when, flutist,
# Nearest to who: he, which, they, pio, there, have, chestnuts, also,
# Nearest to they: we, he, there, you, she, it, who, these,
# Nearest to i: ii, you, we, she, g, mandragora, they, iii,
# Nearest to no: any, another, rebelling, convoluted, radar, a, curtin, operations,
# Nearest to up: out, down, him, off, them, back, accumulated, together,
# Average loss at step 52000: 3.434390
# Average loss at step 54000: 3.422208
# Average loss at step 56000: 3.440601
# Average loss at step 58000: 3.398497
# Average loss at step 60000: 3.394262
# Nearest to can: may, could, would, will, must, might, cannot, should,
# Nearest to than: huntley, much, or, and, problematic, beatified, catastrophe, barclay,
# Nearest to other: various, commotion, many, several, different, including, compromises, aucklanders,
# Nearest to between: with, among, amerindians, da, in, into, within, against,
# Nearest to will: would, could, can, may, must, might, should, does,
# Nearest to on: upon, in, through, at, under, majorities, playlist, marburg,
# Nearest to a: any, another, the, sounding, no, earner, bajan, every,
# Nearest to from: into, through, hawala, photosensitive, in, arousing, wainwright, accentuated,
# Nearest to are: were, is, ideographic, have, be, resembles, those, include,
# Nearest to while: when, although, though, before, after, was, however, where,
# Nearest to by: under, with, through, roost, norbert, mcdaniel, byproducts, vicki,
# Nearest to who: he, which, she, chestnuts, now, also, teleplay, they,
# Nearest to they: we, there, you, he, she, i, it, not,
# Nearest to i: you, we, ii, they, she, iii, mandragora, propose,
# Nearest to no: any, a, rebelling, mobster, brooding, volumes, belo, curtin,
# Nearest to up: out, off, down, him, them, accumulated, together, putative,
# Average loss at step 62000: 3.239436
# Average loss at step 64000: 3.252670
# Average loss at step 66000: 3.405101
# Average loss at step 68000: 3.396307
# Average loss at step 70000: 3.359433
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to than: much, huntley, or, problematic, catastrophe, but, and, beatified,
# Nearest to other: various, commotion, including, different, others, magellan, many, houdini,
# Nearest to between: with, among, within, da, through, from, amerindians, asymmetry,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to on: upon, through, in, gaucho, endogenous, majorities, about, gouvernement,
# Nearest to a: the, any, another, sounding, perceptions, pelts, pepe, this,
# Nearest to from: into, through, hawala, in, between, wainwright, before, octets,
# Nearest to are: were, have, is, include, although, these, including, those,
# Nearest to while: when, although, though, before, however, after, where, including,
# Nearest to by: through, under, suzanne, skit, ewen, in, using, annuals,
# Nearest to who: which, he, loretta, she, they, chestnuts, we, there,
# Nearest to they: we, there, he, you, she, it, who, these,
# Nearest to i: we, you, ii, g, mandragora, refrains, reinterpretation, collaborative,
# Nearest to no: any, mobster, brooding, belo, rebelling, never, mufti, a,
# Nearest to up: out, off, down, them, him, back, accumulated, together,
# Average loss at step 72000: 3.372868
# Average loss at step 74000: 3.348669
# Average loss at step 76000: 3.315862
# Average loss at step 78000: 3.353840
# Average loss at step 80000: 3.378584
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to than: much, or, huntley, but, problematic, beatified, introspection, while,
# Nearest to other: various, including, yassir, others, commotion, many, houdini, compromises,
# Nearest to between: among, with, within, da, amerindians, in, against, around,
# Nearest to will: would, could, may, can, should, must, might, cannot,
# Nearest to on: upon, in, through, at, hongkong, novak, endogenous, under,
# Nearest to a: another, acker, ej, the, paradigmatic, sounding, sda, orbs,
# Nearest to from: into, through, hawala, across, after, in, segmented, wainwright,
# Nearest to are: were, is, have, include, those, although, these, tentative,
# Nearest to while: though, when, although, after, but, before, however, unless,
# Nearest to by: through, under, when, jehoram, against, byproducts, richey, with,
# Nearest to who: he, she, which, usually, they, sandinista, chestnuts, loretta,
# Nearest to they: we, he, you, there, she, it, who, these,
# Nearest to i: you, we, ii, g, mandragora, iii, she, reinterpretation,
# Nearest to no: any, rebelling, little, never, buprenorphine, harmon, naci, stealth,
# Nearest to up: out, off, down, them, him, together, accumulated, sure,
# Average loss at step 82000: 3.408756
# Average loss at step 84000: 3.413542
# Average loss at step 86000: 3.391015
# Average loss at step 88000: 3.351931
# Average loss at step 90000: 3.365314
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to than: or, much, huntley, problematic, beatified, barclay, mindful, catastrophe,
# Nearest to other: various, yassir, commotion, individual, including, different, mindat, aucklanders,
# Nearest to between: with, within, among, against, da, around, from, amerindians,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to on: upon, through, under, in, lysosome, at, heathers, capitoline,
# Nearest to a: another, sounding, the, every, any, paradigmatic, acker, beaten,
# Nearest to from: into, through, across, after, between, with, towards, by,
# Nearest to are: were, is, have, include, these, although, those, russa,
# Nearest to while: although, when, though, after, before, were, despite, unless,
# Nearest to by: through, when, under, without, surreal, after, hongkong, jehoram,
# Nearest to who: he, which, often, she, also, manichaeism, sandinista, they,
# Nearest to they: we, he, there, you, she, it, these, but,
# Nearest to i: we, g, you, ii, p, mandragora, iii, t,
# Nearest to no: any, befell, become, never, little, mobster, rebelling, harmon,
# Nearest to up: out, off, down, together, back, him, them, sure,
# Average loss at step 92000: 3.398354
# Average loss at step 94000: 3.253711
# Average loss at step 96000: 3.355325
# Average loss at step 98000: 3.239906
# Average loss at step 100000: 3.350879
# Nearest to can: could, may, must, would, will, should, might, cannot,
# Nearest to than: or, much, huntley, slightly, and, accurately, introspection, putting,
# Nearest to other: various, others, individual, including, commotion, different, yassir, haihowak,
# Nearest to between: with, among, da, against, within, amerindians, through, in,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to on: upon, through, in, at, under, scholastic, within, endogenous,
# Nearest to a: the, another, any, sounding, perceptions, ej, sda, acker,
# Nearest to from: into, through, in, across, accentuated, within, by, during,
# Nearest to are: were, have, although, those, include, these, is, while,
# Nearest to while: when, although, though, before, unless, if, after, but,
# Nearest to by: through, under, from, when, dct, ewen, kla, flutist,
# Nearest to who: he, she, which, also, nor, spitzer, actually, billy,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to i: we, you, ii, meow, iii, mandragora, they, quickdraw,
# Nearest to no: any, befell, harmon, another, rebelling, linguistics, curtin, mobster,
# Nearest to up: off, out, together, down, him, back, them, sure,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# I think the only different between CBOW and skip-gram is their train data and label. The skip-gram's training data is CBOW's lable and skip-gram's label is CBOW's training data

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['originated', 'a', 'anarchism', 'term', 'term', 'originated', 'as', 'of']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.087626
# Nearest to american: ganglion, carmen, gein, crustacean, wgn, larwood, sharpened, observing,
# Nearest to he: marty, deposition, kensington, fasci, diaphragm, syed, adequate, plotline,
# Nearest to s: joliot, pogroms, spears, lukoff, oskar, cartesian, showcase, vacuum,
# Nearest to first: standards, heine, ghamdi, keating, madhya, alliance, congreso, villain,
# Nearest to its: spielberg, deem, julian, gays, looping, surroundings, reformatory, shanghainese,
# Nearest to from: enforcement, astronaut, liturgical, hilary, error, percentage, elagabalus, caravans,
# Nearest to zero: domino, emet, apollinaire, candida, gath, stratigraphic, renown, venetians,
# Nearest to this: numismatic, collaborator, politburo, manaus, khayyam, monday, reinvention, als,
# Nearest to been: ste, castilian, liebig, fullerton, archivist, corroborated, uphill, stipulation,
# Nearest to called: fundraiser, internationalism, suspicions, armada, surround, syrups, killed, lump,
# Nearest to so: transmissible, jeff, arctocephalus, taiwanese, politician, lecter, tierra, minneapolis,
# Nearest to d: erratic, lucca, cannons, overtake, salinity, licence, lu, emperors,
# Nearest to to: neural, latgale, aix, embryo, angola, undergraduate, emptied, mawson,
# Nearest to five: bundesl, snack, rs, purebred, smoot, alla, relocate, baruch,
# Nearest to about: subplot, adjacency, urinary, gotha, gradients, treehouse, somewhat, singly,
# Nearest to state: permit, fingerprints, carl, presbyterianism, nemesis, presse, cuvier, guidebook,
# Average loss at step 2000: 4.363748
# Average loss at step 4000: 3.863803
# Average loss at step 6000: 3.786335
# Average loss at step 8000: 3.685027
# Average loss at step 10000: 3.618627
# Nearest to american: llu, comforts, thz, carmen, national, jyutping, ding, locust,
# Nearest to he: it, they, she, there, shutting, who, fasci, we,
# Nearest to s: his, hypotheses, mammoth, galactose, corel, the, ogilvie, cloister,
# Nearest to first: standards, falk, heine, ghamdi, second, dials, keating, congreso,
# Nearest to its: the, their, his, internationale, julian, exceeded, impassable, corgi,
# Nearest to from: in, at, nafta, peppers, through, cherished, anthropologist, protections,
# Nearest to zero: five, six, nine, seven, eight, three, four, two,
# Nearest to this: it, which, the, that, a, hutcheson, erik, aral,
# Nearest to been: unsympathetic, become, is, was, be, archivist, cloak, idiosyncratic,
# Nearest to called: suspicions, fundraiser, handguard, excommunication, physical, amend, internationalism, therapeutic,
# Nearest to so: taiwanese, politician, minneapolis, pandemic, transmissible, lecter, jeff, wallets,
# Nearest to d: b, inverting, roda, overtake, catholic, thermodynamically, heartfelt, and,
# Nearest to to: would, catacombs, ibsen, into, hypomanic, jealously, hex, downplay,
# Nearest to five: six, three, eight, seven, four, nine, zero, two,
# Nearest to about: tariff, gradients, aristotle, wissenschaften, aut, yeltsin, cryptographers, nernst,
# Nearest to state: cuvier, uncommonly, presbyterianism, operator, city, thinking, lithuanian, presse,
# Average loss at step 12000: 3.602976
# Average loss at step 14000: 3.567967
# Average loss at step 16000: 3.413564
# Average loss at step 18000: 3.458212
# Average loss at step 20000: 3.545300
# Nearest to american: australian, british, english, wilhelm, and, flanagan, german, national,
# Nearest to he: she, it, they, who, there, which, faure, then,
# Nearest to s: cloister, gentis, mammoth, barn, vacuum, corrections, deed, interpolating,
# Nearest to first: second, heine, standards, ghamdi, bid, falk, prophecies, dials,
# Nearest to its: their, his, the, impassable, internationale, any, gandhara, muds,
# Nearest to from: nafta, through, at, in, between, rs, into, prinz,
# Nearest to zero: five, six, four, three, seven, eight, nine, two,
# Nearest to this: it, which, that, erik, no, what, the, he,
# Nearest to been: become, be, unsympathetic, was, were, pants, had, withers,
# Nearest to called: handguard, redrawn, excommunication, boo, suspicions, libra, bianca, angeles,
# Nearest to so: taiwanese, minneapolis, pandemic, lecter, even, jeff, cirque, transmissible,
# Nearest to d: b, roda, snipers, inverting, overtake, births, siddhartha, purged,
# Nearest to to: would, can, will, hypomanic, latour, may, not, warbler,
# Nearest to five: six, three, four, seven, eight, two, zero, nine,
# Nearest to about: tariff, aristotle, gradients, gives, autocad, mutagens, wissenschaften, somewhat,
# Nearest to state: uncommonly, wallace, thinking, salk, presse, penguin, buckley, nemesis,
# Average loss at step 22000: 3.504885
# Average loss at step 24000: 3.491437
# Average loss at step 26000: 3.482239
# Average loss at step 28000: 3.479774
# Average loss at step 30000: 3.497239
# Nearest to american: british, australian, english, german, lahoud, national, perceives, locust,
# Nearest to he: she, it, they, who, there, faure, we, upwelling,
# Nearest to s: his, whose, corrections, processors, and, transpose, ceos, opolska,
# Nearest to first: second, last, heine, prophecies, bid, earliest, most, falk,
# Nearest to its: their, his, the, impassable, any, wendell, fucking, adhemar,
# Nearest to from: into, through, nafta, on, in, between, by, after,
# Nearest to zero: five, four, eight, three, six, seven, two, nine,
# Nearest to this: which, it, that, what, determinism, any, a, predicts,
# Nearest to been: become, be, unsympathetic, was, were, already, exonerated, eca,
# Nearest to called: handguard, imaginary, boo, redrawn, lump, zvi, corresponds, excommunication,
# Nearest to so: taiwanese, pandemic, minneapolis, too, mrs, destroyed, castillian, lecter,
# Nearest to d: b, snipers, roda, flourishes, canonised, bureaucrat, ulvaeus, overtake,
# Nearest to to: would, can, should, could, must, hypomanic, will, siliceous,
# Nearest to five: four, seven, eight, three, six, zero, nine, two,
# Nearest to about: tariff, gives, aristotle, aut, anticipated, lupercalia, conic, yeltsin,
# Nearest to state: city, buckley, uncommonly, salk, nemesis, thinking, operator, presse,
# Average loss at step 32000: 3.501262
# Average loss at step 34000: 3.494721
# Average loss at step 36000: 3.450755
# Average loss at step 38000: 3.304290
# Average loss at step 40000: 3.432323
# Nearest to american: british, australian, english, german, perceives, national, incurable, etsi,
# Nearest to he: she, it, they, there, who, garments, i, taylor,
# Nearest to s: mammoth, vacuum, occultism, his, interpolating, branwell, merseburg, assists,
# Nearest to first: second, last, bid, next, rehearsing, deflecting, sultan, acetate,
# Nearest to its: their, his, the, her, confronting, muds, impassable, any,
# Nearest to from: through, into, in, on, uncontrollable, between, nafta, prinz,
# Nearest to zero: five, seven, nine, eight, six, three, four, two,
# Nearest to this: which, it, that, the, what, erik, weeping, any,
# Nearest to been: become, be, unsympathetic, was, already, were, previously, had,
# Nearest to called: imaginary, redrawn, lump, delano, lcc, but, there, groceries,
# Nearest to so: taiwanese, pandemic, mound, mrs, too, destroyed, cirque, minneapolis,
# Nearest to d: b, j, snipers, e, purged, ldapv, roda, flourishes,
# Nearest to to: hypomanic, in, marian, could, and, enormous, platte, will,
# Nearest to five: seven, six, eight, three, four, nine, zero, two,
# Nearest to about: gives, lind, somewhat, anticipated, yelled, adjacency, on, grasshoppers,
# Nearest to state: city, government, operator, nemesis, uncommonly, hermas, buckley, presse,
# Average loss at step 42000: 3.436039
# Average loss at step 44000: 3.451100
# Average loss at step 46000: 3.452104
# Average loss at step 48000: 3.351743
# Average loss at step 50000: 3.379934
# Nearest to american: english, british, australian, german, incurable, dynamically, hagen, perceives,
# Nearest to he: she, it, they, who, there, soon, this, we,
# Nearest to s: vacuum, his, interpolating, marcelo, barn, cloister, does, whose,
# Nearest to first: second, last, next, final, third, heine, most, acetate,
# Nearest to its: their, his, the, her, mercer, confronting, muds, power,
# Nearest to from: through, into, in, between, nafta, khanty, prinz, across,
# Nearest to zero: five, four, eight, seven, six, three, nine, two,
# Nearest to this: which, the, it, what, that, he, aspartame, erik,
# Nearest to been: become, be, already, were, was, unsympathetic, transnistrian, had,
# Nearest to called: named, lump, delano, lcc, honey, imaginary, redrawn, hayes,
# Nearest to so: thus, pandemic, simplifies, mound, cirque, mrs, after, mnr,
# Nearest to d: b, j, snipers, f, roda, e, c, purged,
# Nearest to to: deadliest, logistics, should, catacombs, towards, decommissioned, may, helpless,
# Nearest to five: six, seven, four, eight, three, zero, nine, two,
# Nearest to about: gives, anticipated, lind, somewhat, coachella, on, yelled, bfi,
# Nearest to state: operator, city, hermas, government, expositor, uncommonly, salk, nemesis,
# Average loss at step 52000: 3.435444
# Average loss at step 54000: 3.423413
# Average loss at step 56000: 3.434791
# Average loss at step 58000: 3.399782
# Average loss at step 60000: 3.392374
# Nearest to american: british, english, australian, german, dynamically, korean, russian, international,
# Nearest to he: she, it, they, who, soon, tolerate, there, we,
# Nearest to s: interpolating, mammoth, vacuum, deed, barn, does, executors, rabbit,
# Nearest to first: second, last, next, third, final, same, bid, only,
# Nearest to its: their, his, her, the, axelrod, confronting, mercer, cfm,
# Nearest to from: through, in, into, including, prinz, within, between, kemp,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to this: it, which, that, what, determinism, the, some, there,
# Nearest to been: become, be, was, were, already, had, transnistrian, unsympathetic,
# Nearest to called: referred, lump, named, used, honey, benzoate, lcc, leninist,
# Nearest to so: too, brubaker, mound, taiwanese, if, ig, drew, pandemic,
# Nearest to d: b, j, c, f, roda, r, gerardus, snipers,
# Nearest to to: not, would, will, siliceous, may, can, towards, brokerage,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to about: estimated, coachella, accentuate, wavering, yelled, bloemfontein, yeltsin, lind,
# Nearest to state: government, city, operator, hermas, methodology, uncommonly, expositor, stimulating,
# Average loss at step 62000: 3.245184
# Average loss at step 64000: 3.261495
# Average loss at step 66000: 3.401795
# Average loss at step 68000: 3.396768
# Average loss at step 70000: 3.357815
# Nearest to american: british, english, australian, korean, italian, neighbouring, german, dynamically,
# Nearest to he: she, it, they, soon, who, there, we, noticed,
# Nearest to s: marcelo, mammoth, does, whose, tica, isbn, reformulation, inclusive,
# Nearest to first: second, last, next, third, final, bid, same, goldberg,
# Nearest to its: their, his, the, her, mercer, chopping, muds, confronting,
# Nearest to from: through, into, under, across, within, between, uss, invading,
# Nearest to zero: four, five, six, eight, seven, three, nine, two,
# Nearest to this: which, it, the, that, what, another, recessive, determinism,
# Nearest to been: become, be, were, already, was, had, withers, unsympathetic,
# Nearest to called: named, referred, lump, leninist, honey, glam, basileus, redrawn,
# Nearest to so: too, mound, thus, brubaker, if, then, sometimes, apple,
# Nearest to d: b, j, f, r, roda, mueller, snipers, basset,
# Nearest to to: can, will, must, could, would, may, siliceous, in,
# Nearest to five: four, six, three, seven, eight, zero, nine, two,
# Nearest to about: bloemfontein, yelled, saar, yeltsin, estimated, summarizes, conic, accentuate,
# Nearest to state: government, states, operator, city, hermas, methodology, wallace, uncommonly,
# Average loss at step 72000: 3.373343
# Average loss at step 74000: 3.342125
# Average loss at step 76000: 3.319550
# Average loss at step 78000: 3.349565
# Average loss at step 80000: 3.375263
# Nearest to american: british, english, australian, german, irish, international, russian, korean,
# Nearest to he: she, it, they, there, who, we, never, soon,
# Nearest to s: mammoth, gravitons, isbn, gentis, barn, vacuum, liberia, horizontal,
# Nearest to first: second, last, next, third, final, bid, only, same,
# Nearest to its: their, his, her, your, the, our, stimulants, mercer,
# Nearest to from: through, into, across, between, within, nafta, under, uss,
# Nearest to zero: five, seven, four, six, eight, three, nine, two,
# Nearest to this: it, which, determinism, itself, another, he, whichever, the,
# Nearest to been: become, be, already, were, rockers, was, unsympathetic, previously,
# Nearest to called: referred, known, considered, gees, glam, named, cdi, lump,
# Nearest to so: if, then, too, when, seebeck, before, mound, brubaker,
# Nearest to d: b, j, f, bourgeois, mueller, r, flourishes, aussie,
# Nearest to to: will, would, should, indented, hypomanic, siliceous, must, convene,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to about: bloemfontein, estimated, coachella, yeltsin, yelled, pyramidal, morally, wavering,
# Nearest to state: government, city, states, kinetoscope, schedules, stimulating, ammonite, bicameral,
# Average loss at step 82000: 3.408671
# Average loss at step 84000: 3.409116
# Average loss at step 86000: 3.388486
# Average loss at step 88000: 3.350960
# Average loss at step 90000: 3.360947
# Nearest to american: british, english, australian, german, italian, russian, irish, korean,
# Nearest to he: she, it, they, there, who, soon, but, later,
# Nearest to s: whose, mammoth, his, gentis, isbn, sawdust, motherboards, her,
# Nearest to first: second, last, next, final, third, earliest, same, latter,
# Nearest to its: their, his, her, your, the, our, stimulants, mercer,
# Nearest to from: through, into, across, during, within, between, under, tubulin,
# Nearest to zero: five, seven, eight, six, three, four, nine, two,
# Nearest to this: it, which, determinism, the, recessive, another, itself, any,
# Nearest to been: become, be, already, was, previously, rockers, shiraz, remained,
# Nearest to called: referred, named, known, used, considered, gees, upbringing, leninist,
# Nearest to so: too, if, then, thus, seebeck, brubaker, before, sive,
# Nearest to d: b, j, mueller, bourgeois, parodied, f, rcaf, canonised,
# Nearest to to: towards, will, would, siliceous, regnant, astbury, warbler, must,
# Nearest to five: seven, six, four, eight, three, zero, nine, two,
# Nearest to about: bloemfontein, coachella, authorisation, morally, over, yeltsin, pyramidal, yelled,
# Nearest to state: government, city, kinetoscope, bicameral, hermas, states, schedules, stimulating,
# Average loss at step 92000: 3.397173
# Average loss at step 94000: 3.255431
# Average loss at step 96000: 3.359430
# Average loss at step 98000: 3.242266
# Average loss at step 100000: 3.354246
# Nearest to american: british, canadian, australian, italian, english, wolof, taya, lahoud,
# Nearest to he: she, it, they, who, there, we, soon, noticed,
# Nearest to s: whose, his, pasquale, isbn, motherboards, processors, mammoth, gentis,
# Nearest to first: last, second, next, third, final, earliest, heine, bid,
# Nearest to its: their, his, the, your, her, our, stimulants, guybrush,
# Nearest to from: through, into, across, nafta, between, within, uss, rs,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to this: it, which, itself, recessive, he, ayrton, that, determinism,
# Nearest to been: become, be, already, was, previously, were, recently, remained,
# Nearest to called: referred, named, glam, gees, considered, known, benzoate, upbringing,
# Nearest to so: too, then, thus, if, when, sometimes, mcleod, seebeck,
# Nearest to d: b, j, roda, c, snipers, flourishes, h, bureaucrat,
# Nearest to to: will, would, can, should, could, must, might, cannot,
# Nearest to five: seven, six, four, eight, three, nine, two, zero,
# Nearest to about: bloemfontein, coachella, estimated, authorisation, morally, yeltsin, wavering, tenths,
# Nearest to state: city, government, ammonite, stimulating, hermas, violence, states, ottomans,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
